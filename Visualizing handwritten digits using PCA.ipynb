# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
from sklearn.datasets import load_digits

# %%
digits = load_digits()
digits.data.shape
# Out:
# (1797, 64)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2) # projecting 64 dimensions to 2 dimensions
projected = pca.fit_transform(digits.data)
print(projected.shape)
# Out:
# (1797, 2)

# %%
plt.scatter(projected[:, 0], projected[:, 1], c=digits.target, edgecolor='none', alpha=0.5, cmap=plt.cm.get_cmap('spring', 10))
plt.xlabel('component 1')
plt.ylabel('component 2')
plt.colorbar();
# Out:
# /var/folders/kc/4kd0hqq50fzggd1t6ntbxd8r0000gn/T/ipykernel_97894/3786203045.py:1: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   plt.scatter(projected[:, 0], projected[:, 1], c=digits.target, edgecolor='none', alpha=0.5, cmap=plt.cm.get_cmap('spring', 10))
